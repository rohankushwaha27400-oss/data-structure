# %% [markdown]
# sets

# %%
a ={3,5,7,9}

print(a)
print(type(a))
# Out:
# {9, 3, 5, 7}
# <class 'set'>

# %% [markdown]
# Sets Methods

# %%
a = {3, 5, 7, 9,94, 3, 5, 7, 9}

print(a)
a.add(10)
a.add(24)
a.remove(3)
a.pop()
print(a)
# Out:
# {3, 5, 7, 9, 94}
# {7, 24, 9, 10, 94}

# %% [markdown]
# Sets Operations

# %%
a = {3, 5, 7, 9}
b = {5, 7, 9, 11, 13}

print(a.union(b))
print(a.intersection(b))
# Out:
# {3, 5, 7, 9, 11, 13}
# {9, 5, 7}
