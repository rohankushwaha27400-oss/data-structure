# %% [markdown]
# Methods of Lists

# %%
marks = [23,65,89,34,12]
extra_marks = [45, 67, 78, 90, 56]

print("Marks:", marks)
marks.extend(extra_marks)
print("Updated Marks:", marks)
# Out:
# Marks: [23, 65, 89, 34, 12]
# Updated Marks: [23, 65, 89, 34, 12, 45, 67, 78, 90, 56]

# %% [markdown]
# List Containing Table

# %%
table = [5*i for i in range(1, 11)]

print("Multiplication Table of 5:", table)
# Out:
# Multiplication Table of 5: [5, 10, 15, 20, 25, 30, 35, 40, 45, 50]
